# %% [markdown]
# An off-lattice particle-cluster polydisperse tunable sequential aggregation (PTSA) algorithm by Singh and Tsotas 2022, https://doi.org/10.1016/j.ces.2021.117022

# %%
import numpy as np
import numba

# %%
@numba.njit
def ptsa(Np, mean_rp, rel_std_rp, Df, k, max_search_num, rng):
    """
    PTSA function (optimized)

    Polydisperse tunable sequential aggregation (PTSA) method for generating fractal-like aggregate.
    Monomer radius follows a normal distribution with specified mean and standard deviation.
    The algorithms might fail depending on the combination of (k, Df).
    N.Moteki tested only k=0.95, and Df= 2.35~2.95, 

    Optimization over ptsa_original: the inner distance-check loop uses early exit on overlap
    detection, avoiding full O(ip) distance scans for rejected candidates.
    Numerical results are bit-identical to ptsa_original for the same rng seed.

    ==== Input parameters ===
    Np: number of monomers
    mean_rp: mean of the normal distribution of the monomer radius
    rel_std_rp: relative standard deviation of the normal distrituion of the monomer radius 
    Df: fractal dimension
    k: fractal prefactor
    max_search_num: maximum number of iteration for searching a location of each monomer attached onto the surface of an aggregate (= 20000000)
    rng: random number generator constructed by the numpy.random.default_rng()

    === Output variables ===
    Np_final: number of monomers in the generated aggregate. If the aggregate generation failed, Np_final < Np.
    xp: (x,y,z) coordinate of the center of individual monomers relative to the centroid of the aggregate. 2D of shape= (Np,3).
    rp: radii of individual monomers. 1D array of size= Np.
    V: volume of the aggregate.
    Rve: volume-equivalent radius of the aggregate.
    Rg: gyration radius of aggregate.
    eps_agg: porosity of the aggregate calculated using the gyration method.

    reference: 
    Singh and Tsotas 2022, https://doi.org/10.1016/j.ces.2021.117022  

    Coded and tested by Nobuhiro Moteki, 2023-Jan-29th
    Optimized by Claude (early-exit distance loop), 2026-Mar-09th
    """

    #torelance of inter-monomer separation between attached monomers
    tol = 0.001+(2.95-Df)*0.0033 #tol= 0.001 @ Df=2.95, tol=0.003 @ Df=2.35

    # box muller method for genarating standard normal random vairable snv
    u1= rng.random(size= Np)
    u2= rng.random(size= Np)
    r= np.sqrt(-2.0*np.log(u1))
    theta= 2.0*np.pi*u2
    snv= r*np.cos(theta) # random number from the standard normal distribution

    # enforce outliers beyond 2 sigma to the boundary values
    for i, val in enumerate(snv):
        if val < -2:
            snv[i]= -2
        elif val > 2:
            snv[i]= 2

    rp= mean_rp*rel_std_rp*snv + mean_rp # radius of indivitual monomers (normal distribution) 
    density = 1.0 # monomer bulk density
    mp= (4*np.pi/3)*density*rp**3  # mass of individual monomers
    mp3t= np.broadcast_to(mp, (3,Np))
    mp3= mp3t.transpose() 
    xp= np.zeros((Np,3)) # 3D coordinates (x,y,z) of the centers of Np monomers
    minimum_separation= mean_rp*1e-6  # tolerance of intermonomer surface separation [um]

    xp[0,0],xp[0,1],xp[0,2]= 0.0,0.0,0.0
    # generate random point on a unit surface
    phi= rng.random()*2*np.pi
    u= rng.random()*2-1.0
    sqrt1mu2= np.sqrt(1-u**2)
    ux,uy,uz= sqrt1mu2*np.cos(phi), sqrt1mu2*np.sin(phi), u   # random position on the surface of the unit sphere
    R= rp[0]+rp[1]+minimum_separation # distance between the centers of 1st and 2nd monomers
    xp[1,0],xp[1,1],xp[1,2]= R*ux, R*uy, R*uz  # center position of 2nd monomer
    xp[0:2,:]= xp[0:2,:]- np.sum(mp3[0:2,:]*xp[0:2,:],axis=0)/np.sum(mp[0:2]) # shift the centroid to the origin 

    Np_final=0
    for ip in range(2,Np):
        n= ip+1 # index of monomer (3,...,Np)
        Rpn= rp[ip] # radius of n-th monomer
        if n <= k**(3/(3-Df)):
            Df_tuned= 3
        else:
            Df_tuned= Df*(np.log(Np)/np.log(Np/k))  # Step 4. Compute tuned fractal dimension (at k=1) from the actual fractal dimensiton and prefactor (Df, k)
        R2= (n**2*Rpn**2/(n-1))*n**(2/Df_tuned)- (n*Rpn**2/(n-1))- n*Rpn**2*(n-1)**(2/Df_tuned)
        R= np.sqrt(R2)

        #maximum_separation= mean_rp*tol
        maximum_separation= mean_rp*tol*(1 + 5*(ip/Np)*(2.95-Df)/0.6)  # Np and Df dependent tuning for accerelation

        attached_cond= False
        for i_search in range(max_search_num):

            phi= rng.random()*2*np.pi
            u= rng.random()*2-1.0
            sqrt1mu2= np.sqrt(1-u*u)
            x0= R*sqrt1mu2*np.cos(phi)
            x1= R*sqrt1mu2*np.sin(phi)
            x2= R*u  # candidate center location of n-th monomer

            # Early-exit overlap and proximity check.
            # Iterates monomers one by one; breaks immediately on overlap (avoids full O(ip) scan).
            # Semantically equivalent to the original np.all / np.any checks.
            overlapping= False
            proximate= False
            for j in range(ip):
                dx= xp[j,0]-x0
                dy= xp[j,1]-x1
                dz= xp[j,2]-x2
                surf_dist= np.sqrt(dx*dx+dy*dy+dz*dz)-(rp[j]+Rpn)
                if surf_dist < minimum_separation:
                    overlapping= True
                    break  # early exit: overlap found, no need to check remaining monomers
                if surf_dist < maximum_separation:
                    proximate= True

            if overlapping:
                continue

            if proximate:
                attached_cond= True
                xp[ip,0]= x0
                xp[ip,1]= x1
                xp[ip,2]= x2
                xp[0:n,:]= xp[0:n,:]- np.sum(mp3[0:n,:]*xp[0:n,:],axis=0)/np.sum(mp[0:n]) # shift the centroid to the origin
                break

        Np_final=n
        if not attached_cond:
            break 
         
    if Np_final == Np:
        Rg= np.sqrt((1/np.sum(mp[:]))*np.sum(mp3[:,0]*((xp[:,0]**2+ xp[:,1]**2+ xp[:,2]**2) +3/5*rp[:]**2))) # Gyration radius
        Re= np.sqrt(5/3)*Rg # effectuve radius
        Vagg= 4*np.pi/3*Re**3 # effective volume
        V= np.sum(mp[:])/density # true volume
        Rve= np.cbrt(3*V/(4*np.pi)) # volume equivalent radius
        eps_agg= 1- V/Vagg # porosity
    else:
        Rg= 0
        Re= 0
        Vagg= 0
        V= 0
        Rve= 0
        eps_agg= 0
    
    return Np_final, xp, rp, V, Rve, Rg, eps_agg

# %%
@numba.njit
def ptsa(Np, mean_rp, rel_std_rp, Df, k, max_search_num, rng):
    """
    Polydisperse tunable sequential aggregation (PTSA) method for generating fractal-like aggregate.
    Monomer radius follows a normal distribution with specified mean and standard deviation.
    The algorithms might fail depending on the combination of (k, Df).
    N.Moteki tested only k=0.95, and Df= 2.35~2.95, 

    Inner distance-check loop uses early exit on overlap detection,
    avoiding full O(ip) distance scans for rejected candidates.

    ==== Input parameters ===
    Np: number of monomers
    mean_rp: mean of the normal distribution of the monomer radius
    rel_std_rp: relative standard deviation of the normal distrituion of the monomer radius 
    Df: fractal dimension
    k: fractal prefactor
    max_search_num: maximum number of iteration for searching a location of each monomer attached onto the surface of an aggregate (= 20000000)
    rng: random number generator constructed by the numpy.random.default_rng()

    === Output variables ===
    Np_final: number of monomers in the generated aggregate. If the aggregate generation failed, Np_final < Np.
    xp: (x,y,z) coordinate of the center of individual monomers relative to the centroid of the aggregate. 2D of shape= (Np,3).
    rp: radii of individual monomers. 1D array of size= Np.
    V: volume of the aggregate.
    Rve: volume-equivalent radius of the aggregate.
    Rg: gyration radius of aggregate.
    eps_agg: porosity of the aggregate calculated using the gyration method.

    reference: 
    Singh and Tsotas 2022, https://doi.org/10.1016/j.ces.2021.117022  

    Coded and tested by Nobuhiro Moteki, 2023-Jan-29th
    Optimized by Claude (early-exit distance loop), 2026-Mar-09th
    """

    #torelance of inter-monomer separation between attached monomers
    tol = 0.001+(2.95-Df)*0.0033 #tol= 0.001 @ Df=2.95, tol=0.003 @ Df=2.35

    # box muller method for genarating standard normal random vairable snv
    u1= rng.random(size= Np)
    u2= rng.random(size= Np)
    r= np.sqrt(-2.0*np.log(u1))
    theta= 2.0*np.pi*u2
    snv= r*np.cos(theta) # random number from the standard normal distribution

    # enforce outliers beyond 2 sigma to the boundary values
    for i, val in enumerate(snv):
        if val < -2:
            snv[i]= -2
        elif val > 2:
            snv[i]= 2

    rp= mean_rp*rel_std_rp*snv + mean_rp # radius of indivitual monomers (normal distribution) 
    density = 1.0 # monomer bulk density
    mp= (4*np.pi/3)*density*rp**3  # mass of individual monomers
    mp3t= np.broadcast_to(mp, (3,Np))
    mp3= mp3t.transpose() 
    xp= np.zeros((Np,3)) # 3D coordinates (x,y,z) of the centers of Np monomers
    minimum_separation= mean_rp*1e-6  # tolerance of intermonomer surface separation [um]

    xp[0,0],xp[0,1],xp[0,2]= 0.0,0.0,0.0
    # generate random point on a unit surface
    phi= rng.random()*2*np.pi
    u= rng.random()*2-1.0
    sqrt1mu2= np.sqrt(1-u**2)
    ux,uy,uz= sqrt1mu2*np.cos(phi), sqrt1mu2*np.sin(phi), u   # random position on the surface of the unit sphere
    R= rp[0]+rp[1]+minimum_separation # distance between the centers of 1st and 2nd monomers
    xp[1,0],xp[1,1],xp[1,2]= R*ux, R*uy, R*uz  # center position of 2nd monomer
    xp[0:2,:]= xp[0:2,:]- np.sum(mp3[0:2,:]*xp[0:2,:],axis=0)/np.sum(mp[0:2]) # shift the centroid to the origin 

    Np_final=0
    for ip in range(2,Np):
        n= ip+1 # index of monomer (3,...,Np)
        Rpn= rp[ip] # radius of n-th monomer
        if n <= k**(3/(3-Df)):
            Df_tuned= 3
        else:
            Df_tuned= Df*(np.log(Np)/np.log(Np/k))  # Step 4. Compute tuned fractal dimension (at k=1) from the actual fractal dimensiton and prefactor (Df, k)
        R2= (n**2*Rpn**2/(n-1))*n**(2/Df_tuned)- (n*Rpn**2/(n-1))- n*Rpn**2*(n-1)**(2/Df_tuned)
        R= np.sqrt(R2)

        #maximum_separation= mean_rp*tol
        maximum_separation= mean_rp*tol*(1 + 5*(ip/Np)*(2.95-Df)/0.6)  # Np and Df dependent tuning for accerelation

        attached_cond= False
        for i_search in range(max_search_num):

            phi= rng.random()*2*np.pi
            u= rng.random()*2-1.0
            sqrt1mu2= np.sqrt(1-u*u)
            x0= R*sqrt1mu2*np.cos(phi)
            x1= R*sqrt1mu2*np.sin(phi)
            x2= R*u  # candidate center location of n-th monomer

            # Early-exit overlap and proximity check.
            # Iterates monomers one by one; breaks immediately on overlap (avoids full O(ip) scan).
            overlapping= False
            proximate= False
            for j in range(ip):
                dx= xp[j,0]-x0
                dy= xp[j,1]-x1
                dz= xp[j,2]-x2
                surf_dist= np.sqrt(dx*dx+dy*dy+dz*dz)-(rp[j]+Rpn)
                if surf_dist < minimum_separation:
                    overlapping= True
                    break  # early exit: overlap found, no need to check remaining monomers
                if surf_dist < maximum_separation:
                    proximate= True

            if overlapping:
                continue

            if proximate:
                attached_cond= True
                xp[ip,0]= x0
                xp[ip,1]= x1
                xp[ip,2]= x2
                xp[0:n,:]= xp[0:n,:]- np.sum(mp3[0:n,:]*xp[0:n,:],axis=0)/np.sum(mp[0:n]) # shift the centroid to the origin
                break

        Np_final=n
        if not attached_cond:
            break 
         
    if Np_final == Np:
        Rg= np.sqrt((1/np.sum(mp[:]))*np.sum(mp3[:,0]*((xp[:,0]**2+ xp[:,1]**2+ xp[:,2]**2) +3/5*rp[:]**2))) # Gyration radius
        Re= np.sqrt(5/3)*Rg # effectuve radius
        Vagg= 4*np.pi/3*Re**3 # effective volume
        V= np.sum(mp[:])/density # true volume
        Rve= np.cbrt(3*V/(4*np.pi)) # volume equivalent radius
        eps_agg= 1- V/Vagg # porosity
    else:
        Rg= 0
        Re= 0
        Vagg= 0
        V= 0
        Rve= 0
        eps_agg= 0
    
    return Np_final, xp, rp, V, Rve, Rg, eps_agg

# %%
### pre-execution of ptsa for njit compilation (User should not edit this cell) ### 

mean_rp = 0.02 # mean monomer radius [um]  (user input)
rel_std_rp = 0.1 # relative standard deviation of monomer radius [-]  (user input)
Df =2.9 # fractal dimension (Df< 2.95)
k =0.9 # fractal prefactor (k<= 0.95)
max_search_num= 1000000

Np=20
rng = np.random.default_rng()
Np_final, xp, rp, V, Rve, Rg, eps_agg = ptsa(Np, mean_rp, rel_std_rp, Df, k, max_search_num, rng)

# %%
mean_rp = 0.02 # mean monomer radius [um]  (user input)
rel_std_rp = 0.1 # relative standard deviation of monomer radius [-]  (user input)

# range of the number of monomers
Np_min= 20
Np_max= 2000
num_Np= 5  # Number of Np grid points between Np_min and Np_max (logspace)

# range of the fractal dimension
Df_min= 2.35 #(default)
Df_max= 2.95 #(default)
num_Df= 13  # Number of Df grid points between Df_min and Df_max (linspace)

k =0.95 # fractal prefactor 

# index list of random aggregates
agg_num_arr= [0,1,2]

# %%
### execution of the njitted ptsa ### 

max_search_num= 100000000
max_try_num=10

Df_arr= np.linspace(start=Df_min, stop=Df_max, num=num_Df)
Np_arr= np.floor(np.logspace(start= np.log10(Np_min), stop= np.log10(Np_max), num=num_Np)).astype(int)

folder_path= "./generated_agg_files/"

import time

for agg_num in agg_num_arr:
    for Df in Df_arr:
        for Np in Np_arr:
            for i_try in range(max_try_num):
                print("agg_num={:02d}, i_try= {:02d}".format(agg_num, i_try), flush= True)
                rng = np.random.default_rng()
                time_sta = time.perf_counter()
                Np_final, xp, rp, V, Rve, Rg, eps_agg = ptsa(Np, mean_rp, rel_std_rp, Df, k, max_search_num, rng)
                time_end = time.perf_counter()
                tim_min = (time_end- time_sta)/60
                print("Np={:05d}, Np_final={:05d}, Execution time= {:5.2f} min".format(Np, Np_final, tim_min), flush= True)
                if not Np_final == Np:
                    # aggregate generation failed
                    if i_try == max_try_num-1:
                        ofname= "agg_num={:01d}_k={:5.3f}_Df={:4.2f}_meanRp={:5.3f}um_rstdRp={:4.2f}_Np={:05d}_Rve={:5.3f}um_Rg={:5.3f}um_epsagg={:5.3f}.ptsa".format(agg_num, k, Df, mean_rp, rel_std_rp, Np, Rve, Rg, eps_agg)
                        print(ofname+" failed!")
                        with open(folder_path + ofname, 'w') as f:
                            f.write("agg generation failed")
                    else:
                        continue
                else:
                    # aggregate generation succeeded
                    ofname= "agg_num={:01d}_k={:5.3f}_Df={:4.2f}_meanRp={:5.3f}um_rstdRp={:4.2f}_Np={:05d}_Rve={:5.3f}um_Rg={:5.3f}um_epsagg={:5.3f}.ptsa".format(agg_num, k, Df, mean_rp, rel_std_rp, Np, Rve, Rg, eps_agg)
                    print(ofname+" generated!", flush= True)

                    # write the (x,y,z,rp) to file
                    with open(folder_path + ofname, 'w') as f:
                        for ip in range(Np):
                            line= "{:13.7e}  {:13.7e}  {:13.7e}  {:13.7e}".format(xp[ip,0],xp[ip,1],xp[ip,2],rp[ip])
                            f.write(line + '\n')
                    break
# Out:
# agg_num=00, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.35_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.056um_Rg=0.074um_epsagg=0.800.ptsa generated!
# agg_num=00, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.35_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.078um_Rg=0.120um_epsagg=0.871.ptsa generated!
# agg_num=00, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.35_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.118um_Rg=0.198um_epsagg=0.902.ptsa generated!
# agg_num=00, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.35_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.175um_Rg=0.331um_epsagg=0.932.ptsa generated!
# agg_num=00, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.07 min
# agg_num=0_k=0.950_Df=2.35_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.255um_Rg=0.537um_epsagg=0.950.ptsa generated!
# agg_num=00, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.40_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.054um_Rg=0.069um_epsagg=0.776.ptsa generated!
# agg_num=00, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.40_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.081um_Rg=0.118um_epsagg=0.851.ptsa generated!
# agg_num=00, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.40_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.119um_Rg=0.191um_epsagg=0.888.ptsa generated!
# agg_num=00, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.40_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.173um_Rg=0.309um_epsagg=0.919.ptsa generated!
# agg_num=00, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.06 min
# agg_num=0_k=0.950_Df=2.40_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.254um_Rg=0.500um_epsagg=0.939.ptsa generated!
# agg_num=00, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.45_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.055um_Rg=0.072um_epsagg=0.792.ptsa generated!
# agg_num=00, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.45_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.080um_Rg=0.114um_epsagg=0.837.ptsa generated!
# agg_num=00, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.45_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.117um_Rg=0.180um_epsagg=0.875.ptsa generated!
# agg_num=00, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.45_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.173um_Rg=0.295um_epsagg=0.906.ptsa generated!
# agg_num=00, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.05 min
# agg_num=0_k=0.950_Df=2.45_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.254um_Rg=0.470um_epsagg=0.926.ptsa generated!
# agg_num=00, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.50_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.058um_Rg=0.072um_epsagg=0.760.ptsa generated!
# agg_num=00, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.50_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.082um_Rg=0.111um_epsagg=0.817.ptsa generated!
# agg_num=00, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.50_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.117um_Rg=0.175um_epsagg=0.859.ptsa generated!
# agg_num=00, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.50_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.174um_Rg=0.278um_epsagg=0.886.ptsa generated!
# agg_num=00, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.04 min
# agg_num=0_k=0.950_Df=2.50_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.254um_Rg=0.440um_epsagg=0.911.ptsa generated!
# agg_num=00, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.55_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.055um_Rg=0.067um_epsagg=0.739.ptsa generated!
# agg_num=00, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.55_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.081um_Rg=0.107um_epsagg=0.804.ptsa generated!
# agg_num=00, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.55_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.116um_Rg=0.165um_epsagg=0.837.ptsa generated!
# agg_num=00, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.55_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.174um_Rg=0.264um_epsagg=0.867.ptsa generated!
# agg_num=00, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.04 min
# agg_num=0_k=0.950_Df=2.55_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.254um_Rg=0.415um_epsagg=0.893.ptsa generated!
# agg_num=00, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.60_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.055um_Rg=0.065um_epsagg=0.718.ptsa generated!
# agg_num=00, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.60_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.081um_Rg=0.104um_epsagg=0.782.ptsa generated!
# agg_num=00, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.60_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.118um_Rg=0.163um_epsagg=0.823.ptsa generated!
# agg_num=00, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.60_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.173um_Rg=0.249um_epsagg=0.843.ptsa generated!
# agg_num=00, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.04 min
# agg_num=0_k=0.950_Df=2.60_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.254um_Rg=0.391um_epsagg=0.871.ptsa generated!
# agg_num=00, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.65_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.056um_Rg=0.064um_epsagg=0.686.ptsa generated!
# agg_num=00, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.65_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.081um_Rg=0.099um_epsagg=0.740.ptsa generated!
# agg_num=00, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.65_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.118um_Rg=0.154um_epsagg=0.790.ptsa generated!
# agg_num=00, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.65_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.173um_Rg=0.241um_epsagg=0.828.ptsa generated!
# agg_num=00, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.04 min
# agg_num=0_k=0.950_Df=2.65_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.255um_Rg=0.372um_epsagg=0.850.ptsa generated!
# agg_num=00, i_try= 00
# Np=00020, Np_final=00003, Execution time=  0.05 min
# agg_num=00, i_try= 01
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.70_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.055um_Rg=0.061um_epsagg=0.659.ptsa generated!
# agg_num=00, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.70_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.080um_Rg=0.098um_epsagg=0.743.ptsa generated!
# agg_num=00, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.70_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.118um_Rg=0.149um_epsagg=0.769.ptsa generated!
# agg_num=00, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.70_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.173um_Rg=0.228um_epsagg=0.797.ptsa generated!
# agg_num=00, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.04 min
# agg_num=0_k=0.950_Df=2.70_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.255um_Rg=0.351um_epsagg=0.822.ptsa generated!
# agg_num=00, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.75_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.055um_Rg=0.061um_epsagg=0.660.ptsa generated!
# agg_num=00, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.75_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.079um_Rg=0.091um_epsagg=0.703.ptsa generated!
# agg_num=00, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.75_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.118um_Rg=0.144um_epsagg=0.745.ptsa generated!
# agg_num=00, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.75_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.173um_Rg=0.219um_epsagg=0.770.ptsa generated!
# agg_num=00, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.04 min
# agg_num=0_k=0.950_Df=2.75_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.255um_Rg=0.333um_epsagg=0.793.ptsa generated!
# agg_num=00, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.80_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.055um_Rg=0.059um_epsagg=0.627.ptsa generated!
# agg_num=00, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.80_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.081um_Rg=0.092um_epsagg=0.684.ptsa generated!
# agg_num=00, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.80_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.119um_Rg=0.138um_epsagg=0.708.ptsa generated!
# agg_num=00, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.80_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.174um_Rg=0.211um_epsagg=0.739.ptsa generated!
# agg_num=00, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.04 min
# agg_num=0_k=0.950_Df=2.80_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.254um_Rg=0.316um_epsagg=0.760.ptsa generated!
# agg_num=00, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.85_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.054um_Rg=0.057um_epsagg=0.618.ptsa generated!
# agg_num=00, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.85_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.082um_Rg=0.093um_epsagg=0.677.ptsa generated!
# agg_num=00, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.85_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.117um_Rg=0.132um_epsagg=0.678.ptsa generated!
# agg_num=00, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.85_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.173um_Rg=0.202um_epsagg=0.710.ptsa generated!
# agg_num=00, i_try= 00
# Np=02000, Np_final=00003, Execution time=  0.05 min
# agg_num=00, i_try= 01
# Np=02000, Np_final=02000, Execution time=  0.05 min
# agg_num=0_k=0.950_Df=2.85_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.254um_Rg=0.302um_epsagg=0.723.ptsa generated!
# agg_num=00, i_try= 00
# Np=00020, Np_final=00003, Execution time=  0.05 min
# agg_num=00, i_try= 01
# Np=00020, Np_final=00003, Execution time=  0.06 min
# agg_num=00, i_try= 02
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.90_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.056um_Rg=0.058um_epsagg=0.590.ptsa generated!
# agg_num=00, i_try= 00
# Np=00063, Np_final=00003, Execution time=  0.05 min
# agg_num=00, i_try= 01
# Np=00063, Np_final=00003, Execution time=  0.05 min
# agg_num=00, i_try= 02
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.90_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.079um_Rg=0.085um_epsagg=0.626.ptsa generated!
# agg_num=00, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.90_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.119um_Rg=0.130um_epsagg=0.647.ptsa generated!
# agg_num=00, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.01 min
# agg_num=0_k=0.950_Df=2.90_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.173um_Rg=0.194um_epsagg=0.667.ptsa generated!
# agg_num=00, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.06 min
# agg_num=0_k=0.950_Df=2.90_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.254um_Rg=0.288um_epsagg=0.681.ptsa generated!
# agg_num=00, i_try= 00
# Np=00020, Np_final=00003, Execution time=  0.05 min
# agg_num=00, i_try= 01
# Np=00020, Np_final=00003, Execution time=  0.05 min
# agg_num=00, i_try= 02
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.95_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.055um_Rg=0.056um_epsagg=0.542.ptsa generated!
# agg_num=00, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.95_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.079um_Rg=0.084um_epsagg=0.612.ptsa generated!
# agg_num=00, i_try= 00
# Np=00200, Np_final=00003, Execution time=  0.05 min
# agg_num=00, i_try= 01
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=0_k=0.950_Df=2.95_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.118um_Rg=0.128um_epsagg=0.634.ptsa generated!
# agg_num=00, i_try= 00
# Np=00632, Np_final=00003, Execution time=  0.05 min
# agg_num=00, i_try= 01
# Np=00632, Np_final=00632, Execution time=  0.01 min
# agg_num=0_k=0.950_Df=2.95_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.172um_Rg=0.186um_epsagg=0.633.ptsa generated!
# agg_num=00, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.10 min
# agg_num=0_k=0.950_Df=2.95_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.254um_Rg=0.276um_epsagg=0.637.ptsa generated!
# agg_num=01, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.35_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.054um_Rg=0.078um_epsagg=0.840.ptsa generated!
# agg_num=01, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.35_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.080um_Rg=0.121um_epsagg=0.863.ptsa generated!
# agg_num=01, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.35_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.118um_Rg=0.200um_epsagg=0.904.ptsa generated!
# agg_num=01, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.35_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.175um_Rg=0.331um_epsagg=0.932.ptsa generated!
# agg_num=01, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.07 min
# agg_num=1_k=0.950_Df=2.35_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.253um_Rg=0.533um_epsagg=0.950.ptsa generated!
# agg_num=01, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.40_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.055um_Rg=0.073um_epsagg=0.803.ptsa generated!
# agg_num=01, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.40_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.080um_Rg=0.118um_epsagg=0.853.ptsa generated!
# agg_num=01, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.40_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.118um_Rg=0.191um_epsagg=0.889.ptsa generated!
# agg_num=01, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.40_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.174um_Rg=0.309um_epsagg=0.918.ptsa generated!
# agg_num=01, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.06 min
# agg_num=1_k=0.950_Df=2.40_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.254um_Rg=0.500um_epsagg=0.939.ptsa generated!
# agg_num=01, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.45_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.054um_Rg=0.069um_epsagg=0.777.ptsa generated!
# agg_num=01, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.45_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.080um_Rg=0.113um_epsagg=0.839.ptsa generated!
# agg_num=01, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.45_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.118um_Rg=0.181um_epsagg=0.871.ptsa generated!
# agg_num=01, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.45_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.173um_Rg=0.291um_epsagg=0.903.ptsa generated!
# agg_num=01, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.05 min
# agg_num=1_k=0.950_Df=2.45_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.254um_Rg=0.468um_epsagg=0.926.ptsa generated!
# agg_num=01, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.50_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.054um_Rg=0.066um_epsagg=0.742.ptsa generated!
# agg_num=01, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.50_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.079um_Rg=0.108um_epsagg=0.814.ptsa generated!
# agg_num=01, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.50_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.118um_Rg=0.172um_epsagg=0.849.ptsa generated!
# agg_num=01, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.50_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.173um_Rg=0.277um_epsagg=0.887.ptsa generated!
# agg_num=01, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.05 min
# agg_num=1_k=0.950_Df=2.50_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.253um_Rg=0.437um_epsagg=0.910.ptsa generated!
# agg_num=01, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.55_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.056um_Rg=0.068um_epsagg=0.742.ptsa generated!
# agg_num=01, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.55_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.082um_Rg=0.109um_epsagg=0.800.ptsa generated!
# agg_num=01, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.55_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.118um_Rg=0.167um_epsagg=0.836.ptsa generated!
# agg_num=01, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.55_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.174um_Rg=0.267um_epsagg=0.871.ptsa generated!
# agg_num=01, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.04 min
# agg_num=1_k=0.950_Df=2.55_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.254um_Rg=0.414um_epsagg=0.893.ptsa generated!
# agg_num=01, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.60_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.053um_Rg=0.063um_epsagg=0.722.ptsa generated!
# agg_num=01, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.60_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.079um_Rg=0.101um_epsagg=0.775.ptsa generated!
# agg_num=01, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.60_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.118um_Rg=0.163um_epsagg=0.822.ptsa generated!
# agg_num=01, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.60_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.172um_Rg=0.250um_epsagg=0.848.ptsa generated!
# agg_num=01, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.04 min
# agg_num=1_k=0.950_Df=2.60_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.254um_Rg=0.389um_epsagg=0.871.ptsa generated!
# agg_num=01, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.65_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.055um_Rg=0.063um_epsagg=0.692.ptsa generated!
# agg_num=01, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.65_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.080um_Rg=0.098um_epsagg=0.747.ptsa generated!
# agg_num=01, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.65_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.119um_Rg=0.156um_epsagg=0.792.ptsa generated!
# agg_num=01, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.65_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.172um_Rg=0.236um_epsagg=0.821.ptsa generated!
# agg_num=01, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.04 min
# agg_num=1_k=0.950_Df=2.65_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.254um_Rg=0.370um_epsagg=0.848.ptsa generated!
# agg_num=01, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.70_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.055um_Rg=0.062um_epsagg=0.669.ptsa generated!
# agg_num=01, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.70_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.082um_Rg=0.097um_epsagg=0.723.ptsa generated!
# agg_num=01, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.70_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.119um_Rg=0.153um_epsagg=0.780.ptsa generated!
# agg_num=01, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.70_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.174um_Rg=0.229um_epsagg=0.796.ptsa generated!
# agg_num=01, i_try= 00
# Np=02000, Np_final=00003, Execution time=  0.05 min
# agg_num=01, i_try= 01
# Np=02000, Np_final=02000, Execution time=  0.04 min
# agg_num=1_k=0.950_Df=2.70_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.253um_Rg=0.349um_epsagg=0.822.ptsa generated!
# agg_num=01, i_try= 00
# Np=00020, Np_final=00003, Execution time=  0.06 min
# agg_num=01, i_try= 01
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.75_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.056um_Rg=0.062um_epsagg=0.651.ptsa generated!
# agg_num=01, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.75_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.080um_Rg=0.092um_epsagg=0.698.ptsa generated!
# agg_num=01, i_try= 00
# Np=00200, Np_final=00003, Execution time=  0.05 min
# agg_num=01, i_try= 01
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.75_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.118um_Rg=0.144um_epsagg=0.746.ptsa generated!
# agg_num=01, i_try= 00
# Np=00632, Np_final=00003, Execution time=  0.05 min
# agg_num=01, i_try= 01
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.75_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.172um_Rg=0.219um_epsagg=0.774.ptsa generated!
# agg_num=01, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.04 min
# agg_num=1_k=0.950_Df=2.75_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.254um_Rg=0.333um_epsagg=0.794.ptsa generated!
# agg_num=01, i_try= 00
# Np=00020, Np_final=00003, Execution time=  0.06 min
# agg_num=01, i_try= 01
# Np=00020, Np_final=00003, Execution time=  0.06 min
# agg_num=01, i_try= 02
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.80_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.055um_Rg=0.060um_epsagg=0.639.ptsa generated!
# agg_num=01, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.80_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.080um_Rg=0.089um_epsagg=0.665.ptsa generated!
# agg_num=01, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.80_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.119um_Rg=0.142um_epsagg=0.728.ptsa generated!
# agg_num=01, i_try= 00
# Np=00632, Np_final=00003, Execution time=  0.05 min
# agg_num=01, i_try= 01
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.80_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.172um_Rg=0.210um_epsagg=0.742.ptsa generated!
# agg_num=01, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.04 min
# agg_num=1_k=0.950_Df=2.80_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.254um_Rg=0.317um_epsagg=0.760.ptsa generated!
# agg_num=01, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.85_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.055um_Rg=0.058um_epsagg=0.614.ptsa generated!
# agg_num=01, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.85_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.081um_Rg=0.088um_epsagg=0.636.ptsa generated!
# agg_num=01, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.85_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.118um_Rg=0.134um_epsagg=0.687.ptsa generated!
# agg_num=01, i_try= 00
# Np=00632, Np_final=00003, Execution time=  0.05 min
# agg_num=01, i_try= 01
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.85_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.172um_Rg=0.200um_epsagg=0.700.ptsa generated!
# agg_num=01, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.05 min
# agg_num=1_k=0.950_Df=2.85_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.254um_Rg=0.301um_epsagg=0.721.ptsa generated!
# agg_num=01, i_try= 00
# Np=00020, Np_final=00003, Execution time=  0.05 min
# agg_num=01, i_try= 01
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.90_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.054um_Rg=0.058um_epsagg=0.629.ptsa generated!
# agg_num=01, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.90_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.080um_Rg=0.086um_epsagg=0.620.ptsa generated!
# agg_num=01, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.90_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.119um_Rg=0.129um_epsagg=0.641.ptsa generated!
# agg_num=01, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.01 min
# agg_num=1_k=0.950_Df=2.90_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.174um_Rg=0.195um_epsagg=0.672.ptsa generated!
# agg_num=01, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.06 min
# agg_num=1_k=0.950_Df=2.90_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.255um_Rg=0.289um_epsagg=0.681.ptsa generated!
# agg_num=01, i_try= 00
# Np=00020, Np_final=00003, Execution time=  0.05 min
# agg_num=01, i_try= 01
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.95_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.056um_Rg=0.058um_epsagg=0.587.ptsa generated!
# agg_num=01, i_try= 00
# Np=00063, Np_final=00003, Execution time=  0.05 min
# agg_num=01, i_try= 01
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.95_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.082um_Rg=0.087um_epsagg=0.614.ptsa generated!
# agg_num=01, i_try= 00
# Np=00200, Np_final=00009, Execution time=  0.07 min
# agg_num=01, i_try= 01
# Np=00200, Np_final=00003, Execution time=  0.06 min
# agg_num=01, i_try= 02
# Np=00200, Np_final=00003, Execution time=  0.05 min
# agg_num=01, i_try= 03
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=1_k=0.950_Df=2.95_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.116um_Rg=0.123um_epsagg=0.613.ptsa generated!
# agg_num=01, i_try= 00
# Np=00632, Np_final=00003, Execution time=  0.05 min
# agg_num=01, i_try= 01
# Np=00632, Np_final=00003, Execution time=  0.05 min
# agg_num=01, i_try= 02
# Np=00632, Np_final=00632, Execution time=  0.01 min
# agg_num=1_k=0.950_Df=2.95_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.174um_Rg=0.188um_epsagg=0.629.ptsa generated!
# agg_num=01, i_try= 00
# Np=02000, Np_final=00003, Execution time=  0.05 min
# agg_num=01, i_try= 01
# Np=02000, Np_final=02000, Execution time=  0.10 min
# agg_num=1_k=0.950_Df=2.95_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.255um_Rg=0.275um_epsagg=0.633.ptsa generated!
# agg_num=02, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.35_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.057um_Rg=0.074um_epsagg=0.794.ptsa generated!
# agg_num=02, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.35_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.080um_Rg=0.123um_epsagg=0.872.ptsa generated!
# agg_num=02, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.35_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.119um_Rg=0.204um_epsagg=0.908.ptsa generated!
# agg_num=02, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.35_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.173um_Rg=0.326um_epsagg=0.931.ptsa generated!
# agg_num=02, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.07 min
# agg_num=2_k=0.950_Df=2.35_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.254um_Rg=0.536um_epsagg=0.950.ptsa generated!
# agg_num=02, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.40_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.053um_Rg=0.065um_epsagg=0.758.ptsa generated!
# agg_num=02, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.40_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.079um_Rg=0.117um_epsagg=0.855.ptsa generated!
# agg_num=02, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.40_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.118um_Rg=0.189um_epsagg=0.889.ptsa generated!
# agg_num=02, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.40_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.174um_Rg=0.313um_epsagg=0.921.ptsa generated!
# agg_num=02, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.06 min
# agg_num=2_k=0.950_Df=2.40_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.255um_Rg=0.498um_epsagg=0.938.ptsa generated!
# agg_num=02, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.45_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.052um_Rg=0.068um_epsagg=0.785.ptsa generated!
# agg_num=02, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.45_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.080um_Rg=0.114um_epsagg=0.840.ptsa generated!
# agg_num=02, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.45_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.117um_Rg=0.184um_epsagg=0.881.ptsa generated!
# agg_num=02, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.45_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.173um_Rg=0.292um_epsagg=0.903.ptsa generated!
# agg_num=02, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.05 min
# agg_num=2_k=0.950_Df=2.45_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.255um_Rg=0.467um_epsagg=0.925.ptsa generated!
# agg_num=02, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.50_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.056um_Rg=0.071um_epsagg=0.766.ptsa generated!
# agg_num=02, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.50_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.080um_Rg=0.109um_epsagg=0.814.ptsa generated!
# agg_num=02, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.50_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.119um_Rg=0.177um_epsagg=0.858.ptsa generated!
# agg_num=02, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.50_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.172um_Rg=0.276um_epsagg=0.886.ptsa generated!
# agg_num=02, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.05 min
# agg_num=2_k=0.950_Df=2.50_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.254um_Rg=0.439um_epsagg=0.910.ptsa generated!
# agg_num=02, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.55_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.055um_Rg=0.064um_epsagg=0.709.ptsa generated!
# agg_num=02, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.55_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.081um_Rg=0.107um_epsagg=0.801.ptsa generated!
# agg_num=02, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.55_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.119um_Rg=0.172um_epsagg=0.844.ptsa generated!
# agg_num=02, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.55_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.173um_Rg=0.265um_epsagg=0.870.ptsa generated!
# agg_num=02, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.04 min
# agg_num=2_k=0.950_Df=2.55_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.254um_Rg=0.413um_epsagg=0.892.ptsa generated!
# agg_num=02, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.60_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.055um_Rg=0.065um_epsagg=0.725.ptsa generated!
# agg_num=02, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.60_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.082um_Rg=0.104um_epsagg=0.775.ptsa generated!
# agg_num=02, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.60_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.117um_Rg=0.159um_epsagg=0.812.ptsa generated!
# agg_num=02, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.60_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.173um_Rg=0.251um_epsagg=0.848.ptsa generated!
# agg_num=02, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.04 min
# agg_num=2_k=0.950_Df=2.60_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.254um_Rg=0.390um_epsagg=0.872.ptsa generated!
# agg_num=02, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.65_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.053um_Rg=0.061um_epsagg=0.689.ptsa generated!
# agg_num=02, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.65_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.080um_Rg=0.099um_epsagg=0.752.ptsa generated!
# agg_num=02, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.65_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.117um_Rg=0.155um_epsagg=0.800.ptsa generated!
# agg_num=02, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.65_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.173um_Rg=0.239um_epsagg=0.823.ptsa generated!
# agg_num=02, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.04 min
# agg_num=2_k=0.950_Df=2.65_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.256um_Rg=0.374um_epsagg=0.851.ptsa generated!
# agg_num=02, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.70_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.055um_Rg=0.064um_epsagg=0.708.ptsa generated!
# agg_num=02, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.70_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.080um_Rg=0.098um_epsagg=0.748.ptsa generated!
# agg_num=02, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.70_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.119um_Rg=0.149um_epsagg=0.763.ptsa generated!
# agg_num=02, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.70_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.173um_Rg=0.227um_epsagg=0.795.ptsa generated!
# agg_num=02, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.04 min
# agg_num=2_k=0.950_Df=2.70_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.254um_Rg=0.352um_epsagg=0.825.ptsa generated!
# agg_num=02, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.75_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.057um_Rg=0.063um_epsagg=0.664.ptsa generated!
# agg_num=02, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.75_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.080um_Rg=0.091um_epsagg=0.687.ptsa generated!
# agg_num=02, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.75_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.118um_Rg=0.143um_epsagg=0.741.ptsa generated!
# agg_num=02, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.75_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.174um_Rg=0.219um_epsagg=0.770.ptsa generated!
# agg_num=02, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.04 min
# agg_num=2_k=0.950_Df=2.75_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.255um_Rg=0.333um_epsagg=0.792.ptsa generated!
# agg_num=02, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.80_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.056um_Rg=0.061um_epsagg=0.650.ptsa generated!
# agg_num=02, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.80_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.080um_Rg=0.089um_epsagg=0.665.ptsa generated!
# agg_num=02, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.80_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.118um_Rg=0.139um_epsagg=0.715.ptsa generated!
# agg_num=02, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.80_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.175um_Rg=0.211um_epsagg=0.737.ptsa generated!
# agg_num=02, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.04 min
# agg_num=2_k=0.950_Df=2.80_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.255um_Rg=0.317um_epsagg=0.759.ptsa generated!
# agg_num=02, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.85_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.054um_Rg=0.059um_epsagg=0.634.ptsa generated!
# agg_num=02, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.85_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.079um_Rg=0.086um_epsagg=0.636.ptsa generated!
# agg_num=02, i_try= 00
# Np=00200, Np_final=00003, Execution time=  0.06 min
# agg_num=02, i_try= 01
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.85_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.118um_Rg=0.135um_epsagg=0.690.ptsa generated!
# agg_num=02, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.85_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.174um_Rg=0.201um_epsagg=0.700.ptsa generated!
# agg_num=02, i_try= 00
# Np=02000, Np_final=00003, Execution time=  0.05 min
# agg_num=02, i_try= 01
# Np=02000, Np_final=02000, Execution time=  0.05 min
# agg_num=2_k=0.950_Df=2.85_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.254um_Rg=0.302um_epsagg=0.722.ptsa generated!
# agg_num=02, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.90_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.054um_Rg=0.058um_epsagg=0.620.ptsa generated!
# agg_num=02, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.90_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.079um_Rg=0.083um_epsagg=0.597.ptsa generated!
# agg_num=02, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.90_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.120um_Rg=0.133um_epsagg=0.653.ptsa generated!
# agg_num=02, i_try= 00
# Np=00632, Np_final=00003, Execution time=  0.05 min
# agg_num=02, i_try= 01
# Np=00632, Np_final=00632, Execution time=  0.01 min
# agg_num=2_k=0.950_Df=2.90_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.173um_Rg=0.193um_epsagg=0.668.ptsa generated!
# agg_num=02, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.07 min
# agg_num=2_k=0.950_Df=2.90_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.255um_Rg=0.289um_epsagg=0.682.ptsa generated!
# agg_num=02, i_try= 00
# Np=00020, Np_final=00020, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.95_meanRp=0.020um_rstdRp=0.10_Np=00020_Rve=0.055um_Rg=0.056um_epsagg=0.547.ptsa generated!
# agg_num=02, i_try= 00
# Np=00063, Np_final=00063, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.95_meanRp=0.020um_rstdRp=0.10_Np=00063_Rve=0.081um_Rg=0.085um_epsagg=0.600.ptsa generated!
# agg_num=02, i_try= 00
# Np=00200, Np_final=00200, Execution time=  0.00 min
# agg_num=2_k=0.950_Df=2.95_meanRp=0.020um_rstdRp=0.10_Np=00200_Rve=0.117um_Rg=0.125um_epsagg=0.610.ptsa generated!
# agg_num=02, i_try= 00
# Np=00632, Np_final=00632, Execution time=  0.01 min
# agg_num=2_k=0.950_Df=2.95_meanRp=0.020um_rstdRp=0.10_Np=00632_Rve=0.172um_Rg=0.187um_epsagg=0.636.ptsa generated!
# agg_num=02, i_try= 00
# Np=02000, Np_final=02000, Execution time=  0.11 min
# agg_num=2_k=0.950_Df=2.95_meanRp=0.020um_rstdRp=0.10_Np=02000_Rve=0.255um_Rg=0.276um_epsagg=0.634.ptsa generated!
